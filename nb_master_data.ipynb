# %%
env = dbutils.widgets.get("env")
database = dbutils.widgets.get("database")
schema = dbutils.widgets.get("schema")

spark.sql(f"""
INSERT INTO `{env}_{database}`.`{schema}`.`homes`
SELECT uuid(), 'Aster', 'Asia/Kolkata'
WHERE NOT EXISTS (SELECT 1 FROM `{env}_{database}`.`{schema}`.`homes`);
          """)

spark.sql(f"""
INSERT INTO `{env}_{database}`.`{schema}`.`sensors`
SELECT * FROM (
  SELECT (select home_id from `{env}_{database}`.`{schema}`.`homes`), uuid(), 'Living Room Climate Control', 'TemperatureHumidity', 'Ecobee', 'SmartSensor', uuid(), 'temperature','°C', -10, 50, 15, 30
  UNION ALL
  SELECT (select home_id from `{env}_{database}`.`{schema}`.`homes`), uuid(), 'Living Room Climate Control', 'TemperatureHumidity', 'Ecobee', 'SmartSensor', uuid(), 'Relative Humidity','lux', -10, 50, 15, 30
  UNION ALL
  SELECT (select home_id from `{env}_{database}`.`{schema}`.`homes`), uuid(), 'Kitchen Motion Detector', 'Motion', 'Aqara', 'FP2 Presence Sensor', uuid(), 'Ambient Light','NA', 0, 100000, 0, 2000
  UNION ALL
  SELECT (select home_id from `{env}_{database}`.`{schema}`.`homes`), uuid(), 'Kitchen Motion Detector', 'Motion', 'Aqara', 'FP2 Presence Sensor', uuid(), 'Occupancy Detected','NA', 0, 1, 0, 1
  UNION ALL
  SELECT (select home_id from `{env}_{database}`.`{schema}`.`homes`), uuid(), 'Front Door Sensor', 'Contact', 'Ring', 'Contact Sensor', uuid(), 'Door Status','NA', 0, 1, 0, 1
  UNION ALL
  SELECT (select home_id from `{env}_{database}`.`{schema}`.`homes`), uuid(), 'Hallway Smoke & CO Alarm', 'SmokeCO', 'Google', 'Nest Protect', uuid(), 'Smoke Level','ppm', 0, 1000, 0, 200
  UNION ALL
  SELECT (select home_id from `{env}_{database}`.`{schema}`.`homes`), uuid(), 'Hallway Smoke & CO Alarm', 'SmokeCO', 'Google', 'Nest Protect', uuid(), 'Carbon Monoxide Level','ppm', 0, 1000, 0, 200 
  UNION ALL
  SELECT (select home_id from `{env}_{database}`.`{schema}`.`homes`), uuid(), 'Basement Water Sensor', 'WaterLeak', 'Govee', 'WiFi Water Leak Detector', uuid(), 'Leak Detected','NA', 0, 1, 0, 1
  UNION ALL
  SELECT (select home_id from `{env}_{database}`.`{schema}`.`homes`), uuid(), 'Basement Water Sensor', 'WaterLeak', 'Govee', 'WiFi Water Leak Detector', uuid(), 'Water Flow Rate','lpm', 0, 20, 0, 20
  UNION ALL
  SELECT (select home_id from `{env}_{database}`.`{schema}`.`homes`), uuid(), 'Bedroom Ambient Light Sensor', 'LightSensor', 'Philips', 'Hue Motion Sensor', uuid(), 'Light Intensity','lux', 0, 100000, 0, 1000
  UNION ALL
  SELECT (select home_id from `{env}_{database}`.`{schema}`.`homes`), uuid(), 'Bedroom Ambient Light Sensor', 'LightSensor', 'Philips', 'Hue Motion Sensor', uuid(), 'Color Temperature','K', 0, 10000, 2000, 6500
) AS sensor_data
WHERE NOT EXISTS (SELECT 1 FROM `{env}_{database}`.`{schema}`.`sensors`)
          """)
